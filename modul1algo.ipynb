# %% [markdown]
# <a href="https://colab.research.google.com/github/065002500032-ux/Praktikum_Algoritma/blob/main/modul1algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  """
  Nama = Haekal ramadhan
  NIM = 065002500032
  """
  Nama = input("Masukkan nama anda : ")
  Alamat = input("Masukkan alamat anda : ")
  Kampus = input("Masukkan nama kampus : ")
  Jurusan = input("Masukkan jurusann kamu : ")
  Gedung = input("Masukkan nama gedung kamu : ")
  print(f"Perkenalkan nama saya" , Nama , "saya tinggal" , Alamat , "saya kuliah di" , Kampus , "jurusan" , Jurusan , "di gedung", Gedung , "Dan saya siap ikut praktikum algoritma ")
# Out:
# Masukkan nama anda : Haekal ramadhan
# Masukkan alamat anda : Grand delima ciomas, Bogor
# Masukkan nama kampus : Trisakti
# Masukkan jurusann kamu : Sistem informasi
# Masukkan nama gedung kamu : E
# Perkenalkan nama saya Haekal ramadhan saya tinggal Grand delima ciomas, Bogor saya kuliah di Trisakti jurusan Sistem informasi di gedung E Dan saya siap ikut praktikum algoritma

# %%
"""
Nama = Haekal ramadhan
NIM = 065002500032
"""
Panjang = float(input("Masukkan Panjang ruangan : "))
Lebar = float(input("Masukkan Lebar ruangan : "))
Satuan = input("pilihlah satuan (meter/inci) : ")
if Satuan == "meter":
  luas = Panjang * Lebar
  print(f"luas ruangan {luas}meter")

elif Satuan == "inci":
  Panjang_inci = Panjang * 39.3701
  Lebar_inci = Lebar * 39.3701
  luas = Panjang_inci * Lebar_inci
  print(f"Panjang dalam inci: {Panjang_inci:.2f} inci")
  print(f"lebar dalam inci: {Lebar_inci:.2f} inci")
  print(f"luas ruangan:: {luas:.2f} inci")
# Out:
# Masukkan Panjang ruangan : 5
# Masukkan Lebar ruangan : 5
# pilihlah satuan (meter/inci) : inci
# Panjang dalam inci: 196.85 inci
# lebar dalam inci: 196.85 inci
# luas ruangan:: 38750.12 inci

# %%
"""
Nama = Haekal ramadhan
NIM = 065002500032
"""
print("Hitunglah Body Mass indeks (BMI) !")
Nama = input("Masukkan nama kamu : ")
BB = int(input("Masukkan berat badan kamu : "))
TB = int(input("Masukkan tinggi badan kamu : "))
BMI = BB / TB
print(f" {Nama}, skor BMi kamu adalah {BMI}")
# Out:
# Hitunglah Body Mass indeks (BMI) !
# Masukkan nama kamu : Haekal ramadhan
# Masukkan berat badan kamu : 58
# Masukkan tinggi badan kamu : 171
#  Haekal ramadhan, skor BMi kamu adalah 0.3391812865497076
